# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
people = pd.read_csv('data_all_teams.csv')
people = people.groupby("year")

# %%
people.head()
# Out:
#        year sex     profession   income
# 0         0   F  civil servant  5131.08
# 1         0   M          child     0.00
# 2         0   M     unemployed   124.10
# 3         0   M         farmer  1868.39
# 4         0   F          child     0.00
# ...     ...  ..            ...      ...
# 50447   100   F        retired -1484.72
# 50448   100   F        retired  5207.66
# 50449   100   M        retired  1800.07
# 50450   100   F        retired  1728.71
# 50451   100   X        retired -1355.05
#
# [505 rows x 4 columns]

# %%
gdp = pd.read_csv('data_all_teams_gdp.csv')

# %%
gdp
# Out:
#      year         gdp
# 0       0   947610.99
# 1       1   931427.95
# 2       2   872704.64
# 3       3   875281.14
# 4       4   853371.77
# ..    ...         ...
# 96     96  1226092.63
# 97     97  1202731.04
# 98     98  1196294.53
# 99     99  1216246.99
# 100   100  1123997.05
#
# [101 rows x 2 columns]

# %% [markdown]
# # GDP by years

# %%
plt.figure(figsize=(10, 6))
plt.plot(gdp['year'], gdp['gdp'], marker='o', linestyle='-', color='skyblue', label='GDP')
plt.xlabel("year")
plt.ylabel("gdp")
plt.title("Yearly GDP")
plt.legend()
plt.show()

# %% [markdown]
# # Demographic

# %%
# Count occurrences of each category
job = people["profession"].value_counts()

print(job)
# Out:
# year  profession
# 0     child               124
#       homemaker            74
#       farmer               73
#       fisher               53
#       craftsman            48
#                          ...
# 100   retired              50
#       homemaker            48
#       service provider     35
#       civil servant        30
#       unemployed           30
# Name: count, Length: 908, dtype: int64

# %%
# Count occurrences of each category
sex = people["sex"].value_counts()

# Print summary
print(sex)
# Out:
# year  sex
# 0     M      244
#       F      234
#       X       22
# 1     M      247
#       F      237
#             ...
# 99    M      237
#       X       20
# 100   F      244
#       M      239
#       X       20
# Name: count, Length: 303, dtype: int64

# %%
# Group by Year and calculate the average income
yearly_income = people["income"].mean()

yearly_income.plot(kind='line', color='skyblue')
# Out:
# <Axes: xlabel='year'>
